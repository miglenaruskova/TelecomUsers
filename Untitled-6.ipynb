# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Exploratory Data Analysis and Visualization
# Reading a .csv file

# %%
df = pd.read_csv('telecom_users.xls - telecom_users.xls.csv')

# %%
# take a data information what types, columns and rows

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6050 entries, 0 to 6049
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        6050 non-null   int64
#  1   customerID        6050 non-null   object
#  2   gender            6050 non-null   object
#  3   SeniorCitizen     6050 non-null   int64
#  4   Partner           6050 non-null   object
#  5   Dependents        6050 non-null   object
#  6   tenure            6050 non-null   int64
#  7   PhoneService      6050 non-null   object
#  8   MultipleLines     6050 non-null   object
#  9   InternetService   6050 non-null   object
#  10  OnlineSecurity    6050 non-null   object
#  11  OnlineBackup      6050 non-null   object
#  12  DeviceProtection  6050 non-null   object
#  13  TechSupport       6050 non-null   object
#  14  StreamingTV       6050 non-null   object
#  15  StreamingMovies   6050 non-null   object
# ...

# %%
# Checking the names of the columns

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'customerID', 'gender', 'SeniorCitizen', 'Partner',
#        'Dependents', 'tenure', 'PhoneService', 'MultipleLines',
#        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges', 'TotalCharges',
#        'Churn', 'Provider', 'Age'],
#       dtype='object')

# %%
# Quic look over first 3 data rows

# %%
df.head(3)
# Out:
#    Unnamed: 0  customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0        1869  7010-BRBUU    Male              0     Yes        Yes      72
# 1        4528  9688-YGXVR  Female              0      No         No      44
# 2        6344  9286-DOJGF  Female              1     Yes         No      38
#
#   PhoneService MultipleLines InternetService  ...          StreamingTV  \
# 0          Yes           Yes              No  ...  No internet service
# 1          Yes            No     Fiber optic  ...                  Yes
# 2          Yes           Yes     Fiber optic  ...                   No
#
#        StreamingMovies        Contract PaperlessBilling  \
# 0  No internet service        Two year               No
# 1                   No  Month-to-month              Yes
# 2                   No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges TotalCharges Churn Provider  Age
# ...

# %%
# Make data discription

# %%
df.describe()
# Out:
#         Unnamed: 0  SeniorCitizen       tenure  MonthlyCharges  TotalCharges  \
# count  6050.000000    6050.000000  6050.000000     6050.000000   6040.000000
# mean   3534.521653       0.162149    32.479174       64.836719   2298.114950
# std    2035.721126       0.368618    24.517192       30.099479   2272.518895
# min       0.000000       0.000000     0.000000       18.250000     18.800000
# 25%    1778.250000       0.000000     9.000000       35.750000    405.962500
# 50%    3545.500000       0.000000    29.000000       70.400000   1412.150000
# 75%    5291.750000       0.000000    56.000000       89.900000   3846.450000
# max    7042.000000       1.000000    72.000000      118.750000   8684.800000
#
#        Provider  Age
# count       0.0  0.0
# mean        NaN  NaN
# std         NaN  NaN
# min         NaN  NaN
# 25%         NaN  NaN
# 50%         NaN  NaN
# 75%         NaN  NaN
# max         NaN  NaN

# %%
# Chek for duplicates

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6045    False
# 6046    False
# 6047    False
# 6048    False
# 6049    False
# Length: 6050, dtype: bool

# %%
# data has duplicates

# %%
df.duplicated().sum()
# Out:
# 64

# %%
dfremoveduplicates = df.drop_duplicates()

# %%
# check again the new data after removed duplicates

# %%
dfremoveduplicates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5986 entries, 0 to 6049
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        5986 non-null   int64
#  1   customerID        5986 non-null   object
#  2   gender            5986 non-null   object
#  3   SeniorCitizen     5986 non-null   int64
#  4   Partner           5986 non-null   object
#  5   Dependents        5986 non-null   object
#  6   tenure            5986 non-null   int64
#  7   PhoneService      5986 non-null   object
#  8   MultipleLines     5986 non-null   object
#  9   InternetService   5986 non-null   object
#  10  OnlineSecurity    5986 non-null   object
#  11  OnlineBackup      5986 non-null   object
#  12  DeviceProtection  5986 non-null   object
#  13  TechSupport       5986 non-null   object
#  14  StreamingTV       5986 non-null   object
#  15  StreamingMovies   5986 non-null   object
# ...

# %%
# create a data with important columns and remove the columns which we not use in feture analysis

# %%
dfclean = dfremoveduplicates.drop(['Unnamed: 0','customerID','Provider','Age'], axis=1)

# %%
# 20 more graphics 
# 1 SeniorCitizen visualization
sns.set(style='darkgrid')
sns.countplot(dfclean['SeniorCitizen'])
# Out:
# /Users/miglenaruskova/opt/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='SeniorCitizen', ylabel='count'>

# %%
# 2 Dependents visualization
sns.set(style='darkgrid')
sns.histplot(data=dfclean,x='Dependents')
# Out:
# <AxesSubplot:xlabel='Dependents', ylabel='Count'>

# %%
# 3 Partner visualization
sns.set(style='darkgrid')
sns.histplot(data=dfclean,x='Partner')
# Out:
# <AxesSubplot:xlabel='Partner', ylabel='Count'>

# %%
# 4 Male Subscribers which are Senior Citizens with the following: 'Partner', 'Dependents', 
# 'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
# 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract','TotalCharges','Churn'
df_male = dfclean[(dfclean['gender'] == "Male")&(dfclean['SeniorCitizen'] == 1)]

# %%
dfclean1 = df_male.drop(['gender','SeniorCitizen','tenure',
       'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges'], axis=1)

# %%
dfclean1.head(5)
# Out:
#    Partner Dependents PhoneService MultipleLines InternetService  \
# 9       No         No          Yes           Yes     Fiber optic
# 12     Yes         No          Yes           Yes     Fiber optic
# 54     Yes         No          Yes           Yes     Fiber optic
# 56      No         No          Yes           Yes     Fiber optic
# 61      No         No          Yes           Yes     Fiber optic
#
#    OnlineSecurity OnlineBackup DeviceProtection TechSupport StreamingTV  \
# 9             Yes          Yes              Yes         Yes         Yes
# 12             No           No               No         Yes         Yes
# 54             No          Yes              Yes         Yes         Yes
# 56             No           No               No          No          No
# 61             No           No               No          No         Yes
#
#    StreamingMovies        Contract  TotalCharges Churn
# 9              Yes  Month-to-month       6382.55    No
# ...

# %%
# 5 Female Subscribers which are Senior Citizens with the following: 'Partner', 'Dependents', 
# 'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
# 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract','TotalCharges','Churn'
df_female = dfclean[(dfclean['gender'] == "Female")&(dfclean['SeniorCitizen'] == 1)]

# %%
dfclean1 = df_female.drop(['gender','SeniorCitizen','tenure',
       'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges'], axis=1)

# %%
dfclean1.head(5)
# Out:
#    Partner Dependents PhoneService MultipleLines InternetService  \
# 2      Yes         No          Yes           Yes     Fiber optic
# 24      No         No          Yes            No     Fiber optic
# 25     Yes         No          Yes           Yes     Fiber optic
# 26      No         No          Yes            No             DSL
# 46      No         No          Yes           Yes             DSL
#
#    OnlineSecurity OnlineBackup DeviceProtection TechSupport StreamingTV  \
# 2              No           No               No          No          No
# 24             No           No               No          No          No
# 25            Yes           No               No          No          No
# 26             No           No               No          No          No
# 46             No           No              Yes         Yes          No
#
#    StreamingMovies        Contract  TotalCharges Churn
# 2               No  Month-to-month       2869.85   Yes
# ...

# %%
# 6 Scaterplot with InternetService and Contract divided by Churn
plt.figure(figsize=(12,8))
sns.scatterplot(x='Contract',y='InternetService',data=dfclean,hue='Churn')
# Out:
# <AxesSubplot:xlabel='Contract', ylabel='InternetService'>

# %%
# 7 Countplot on InternetService divided by Churn
plt.figure(figsize=(10,4),dpi=200)
sns.countplot(x='InternetService',data=dfclean, hue='Churn',palette='viridis')
# Out:
# <AxesSubplot:xlabel='InternetService', ylabel='count'>

# %%
# 8 Countplot on InternetService divided by PaymentMethod
plt.figure(figsize=(10,4),dpi=200)
sns.countplot(x='InternetService',data=dfclean, hue='PaymentMethod',palette='viridis')
# Out:
# <AxesSubplot:xlabel='InternetService', ylabel='count'>

# %%
# 9 Countplot on InternetService divided by gender
plt.figure(figsize=(10,4),dpi=200)
sns.countplot(x='InternetService',data=dfclean, hue='gender',palette='viridis')
# Out:
# <AxesSubplot:xlabel='InternetService', ylabel='count'>

# %%
# 10 Countplot on TechSupport divided by Churn
plt.figure(figsize=(10,4),dpi=200)
sns.countplot(x='TechSupport',data=dfclean, hue='Churn',palette='viridis')
# Out:
# <AxesSubplot:xlabel='TechSupport', ylabel='count'>

# %%
# 11 Countplot on MultipleLines divided by Churn
plt.figure(figsize=(10,4),dpi=200)
sns.countplot(x='MultipleLines',data=dfclean, hue='Churn',palette='viridis')
# Out:
# <AxesSubplot:xlabel='MultipleLines', ylabel='count'>

# %%
# 12 Data visualization bethween TotalCharges and PaymentMethod
plt.figure(figsize=(10,6),dpi=200)
# By default barplot() will show the mean
sns.barplot(x='TotalCharges',y='PaymentMethod',data=dfclean,estimator=np.mean,ci='sd')
# Out:
# <AxesSubplot:xlabel='TotalCharges', ylabel='PaymentMethod'>

# %%
# 13 Data visualization bethween tenure and Contract
plt.figure(figsize=(10,6),dpi=200)
# By default barplot() will show the mean
sns.barplot(x='tenure',y='Contract',data=dfclean,estimator=np.mean,ci='sd')
# Out:
# <AxesSubplot:xlabel='tenure', ylabel='Contract'>

# %%
# 14 Data visualization bethween TotalCharges and TechSupport
plt.figure(figsize=(10,6),dpi=200)
# By default barplot() will show the mean
sns.barplot(x='TotalCharges',y='TechSupport',data=dfclean,estimator=np.mean,ci='sd')
# Out:
# <AxesSubplot:xlabel='TotalCharges', ylabel='TechSupport'>

# %%
# 15 Data visualization bethween tenure and Contract
plt.figure(figsize=(10,6),dpi=200)
# By default barplot() will show the mean
sns.barplot(x='tenure',y='Contract',data=df,estimator=np.mean,ci='sd')
# Out:
# <AxesSubplot:xlabel='tenure', ylabel='Contract'>

# %%
clean= dfclean.drop(['gender', 'Partner',
       'Dependents', 'tenure', 'PhoneService', 'MultipleLines',
       'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
       'TechSupport', 'StreamingTV', 'StreamingMovies', 
       'PaperlessBilling', 'MonthlyCharges', 'TotalCharges',
       'Churn'], axis=1)

# %%
# 16 Pairplot which visualise 'SeniorCitizen' and 'PaymentMethod'
sns.pairplot(clean, hue='PaymentMethod')

# %%
# 17 Exploratory Data Analysis and Visualizatiz with heatmap wich show correlation
sns.heatmap(dfclean.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
dfclean['Contract'].unique()
# Out:
# array(['Two year', 'Month-to-month', 'One year'], dtype=object)

# %%
# 18 Exploratory Data Analysis and Visualizatiz with 3D wich show how Contract related with SeniorCitizen, MonthlyCharges and TotalCharges 
from mpl_toolkits.mplot3d import Axes3D 
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
colors = dfclean['Contract'].map({'Two year':0, 'Month-to-month':1, 'One year':2})
ax.scatter(dfclean['SeniorCitizen'],dfclean['MonthlyCharges'],dfclean['TotalCharges'],c=colors);

# %%
dfclean['InternetService'].unique()
# Out:
# array(['No', 'Fiber optic', 'DSL'], dtype=object)

# %%
# 19 Exploratory Data Analysis and Visualizatiz with 3D wich show how InternetService related with SeniorCitizen, MonthlyCharges and TotalCharges 
from mpl_toolkits.mplot3d import Axes3D 
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
colors = dfclean['InternetService'].map({'No':0, 'Fiber optic':1, 'DSL':2})
ax.scatter(dfclean['SeniorCitizen'],dfclean['MonthlyCharges'],dfclean['TotalCharges'],c=colors);

# %%
dfclean['TechSupport'].unique()
# Out:
# array(['No internet service', 'No', 'Yes'], dtype=object)

# %%
# 20 Exploratory Data Analysis and Visualizatiz with 3D wich show how TechSupport related with SeniorCitizen, MonthlyCharges and TotalCharges 
from mpl_toolkits.mplot3d import Axes3D 
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
colors = dfclean['TechSupport'].map({'No internet service':0, 'No':1, 'Yes':2})
ax.scatter(dfclean['SeniorCitizen'],dfclean['MonthlyCharges'],dfclean['TotalCharges'],c=colors);
